# %% [markdown]
# <a href="https://colab.research.google.com/github/Ahmed-Azmy-ELnakib/AMIT_assignment/blob/main/Data_Science%202.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings("ignore")

# %%
data=pd.read_csv("/content/tips.csv")
data=data.copy()

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    object
#  3   smoker      244 non-null    object
#  4   day         244 non-null    object
#  5   time        244 non-null    object
#  6   size        244 non-null    int64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 13.5+ KB

# %%
data
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
data["time"].value_counts()
# Out:
# time
# Dinner    176
# Lunch      68
# Name: count, dtype: int64

# %%
# 1-total_bill:
data.groupby("day").agg({"total_bill":"sum"})
# Out:
#       total_bill
# day
# Fri       325.88
# Sat      1778.40
# Sun      1627.16
# Thur     1096.33

# %%
#2-tip:
data.groupby("sex").agg({"tip":"sum"})
# Out:
#            tip
# sex
# Female  246.51
# Male    485.07

# %%
# 3-sex:
data.groupby("sex").agg({"total_bill":"count"})
# Out:
#         total_bill
# sex
# Female          87
# Male           157

# %%
# 4-smoker:
data.groupby("smoker").agg({"total_bill":"mean"}).round()
# Out:
#         total_bill
# smoker
# No            19.0
# Yes           21.0

# %%
# 5-day:
data.groupby("day").agg({"time":"count"})
# Out:
#       time
# day
# Fri     19
# Sat     87
# Sun     76
# Thur    62

# %%
# 6-time:
data.groupby("time").agg({"tip":"mean"}).round(2)
# Out:
#          tip
# time
# Dinner  3.10
# Lunch   2.73

# %%
# 7-size:
data.groupby("day").agg({"size":"sum"})
# Out:
#       size
# day
# Fri     40
# Sat    219
# Sun    216
# Thur   152

# %%
# Answer 1
data["total_bill"].mean()
# Out:
# 19.78594262295082

# %%
# Answer 2
data.shape[0]
# Out:
# 244

# %%
# Answer 3
Male_tip=data.groupby("sex").agg({"tip":sum}).loc["Male","tip"]
print(Male_tip)
# Out:
# 485.07

# %%
# Answer 4
data["tip"].max()
# Out:
# 10.0

# %%
# Answer 5
data["day"].unique()
# Out:
# array(['Sun', 'Sat', 'Thur', 'Fri'], dtype=object)

# %%
# Answer 6
Female_tip=data.groupby("sex").agg({"tip":sum}).loc["Female","tip"]
print(Female_tip)
# Out:
# 246.51

# %%
# Answer 7
data[data["smoker"] == "No"].shape[0]
# Out:
# 151

# %%
# Answer 8
data.groupby("time").agg({"total_bill":"mean"}).loc["Dinner","total_bill"]
# Out:
# 20.79715909090909

# %%
# Answer 9
data.groupby("size").agg({"total_bill":"mean"}).sort_values(by="total_bill").head(1)
# Out:
#       total_bill
# size
# 1         7.2425

# %%
# Answer 10
data["total_bill"].std()
# Out:
# 8.902411954856856

# %%
# Answer 11
smoker_yes=data[data["smoker"]=="Yes"]
smoker_yes.groupby(data["sex"],).agg({"sex":"count"})
# Out:
#         sex
# sex
# Female   33
# Male     60

# %%
# Answer 12
data.groupby("sex").agg({"tip":"sum"})
# Out:
#            tip
# sex
# Female  246.51
# Male    485.07

# %%
# Answer 13
data[data["day"]=="Thur"].groupby("sex").agg({"tip":"median"})
# Out:
#           tip
# sex
# Female  2.005
# Male    2.530

# %%
# Answer 14
data[data["day"] == "Fri"].groupby("sex").agg({"tip": "sum"})
# Out:
#           tip
# sex
# Female  25.03
# Male    26.93

# %%
# Answer 15
data[data["time"] =="Dinner"].groupby("smoker").agg({"tip":"mean"})
# Out:
#              tip
# smoker
# No      3.126887
# Yes     3.066000

# %%
# Answer 16
data.groupby("smoker").agg({"total_bill":"sum"})
# Out:
#         total_bill
# smoker
# No         2897.43
# Yes        1930.34

# %%
# Answer 17
data.groupby("day").agg({"size":"sum"})
# Out:
#       size
# day
# Fri     40
# Sat    219
# Sun    216
# Thur   152

# %%
# Answer 18
data[data["sex"]=="Female"].groupby("sex").agg({"tip":"max"})
# Out:
#         tip
# sex
# Female  6.5

# %%
# Answer 19
data[data["size"]>=5].groupby("size").agg({"total_bill":"sum"})
# Out:
#       total_bill
# size
# 5         150.34
# 6         139.32

# %%
# Answer 20
data[data["time"] == "Lunch"].groupby("time").agg({"total_bill":"max"})
# Out:
#        total_bill
# time
# Lunch       43.11

# %%
# Answer 21
data[(data["day"] == "Sat") | (data["day"] == "Sun")].groupby("day").agg({"total_bill": "max"})
# Out:
#      total_bill
# day
# Sat       50.81
# Sun       48.17

# %%
data[data["day"].isin(["Sat","Sun"])& (data["total_bill"]>20)].shape[0]
# Out:
# 75
